# %% [markdown]
# Create a UC Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS main.fine_tuning_transformer_model;

# %% [markdown]
# Create a UC Volume

# %%
# %sql
CREATE VOLUME IF NOT EXISTS main.fine_tuning_transformer_model.files

# %%
# %sql
CREATE VOLUME IF NOT EXISTS main.fine_tuning_transformer_model.tmp

# %% [markdown]
# At this point, you should have already created a Unity Catalog schema named `fine_tuning_transformer_model` within the `main` catalog, and a UC volume named `fine_tuning_transformer_model` mapped to this schema.
#
# Now it's time to move parquet files into the Unity Catalog volume.
